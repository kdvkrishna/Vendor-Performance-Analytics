# %%
# INITIAL SETUP
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# Database Connection
engine = create_engine('postgresql://postgres:gtsr@localhost:5432/vendor_performance')

# %%
# --- DATA AUDIT ---

query_tables = """
SELECT table_name FROM information_schema.tables 
WHERE table_schema = 'public' AND table_type = 'BASE TABLE';
"""
tables = pd.read_sql(query_tables, con=engine)['table_name'].tolist()
tables
# Out:
# ['begin_inventory',
#  'end_inventory',
#  'purchases',
#  'purchase_prices',
#  'sales',
#  'vendor_invoice']

# %%
print("--- Database Audit ---")

for i in tables:
    print('-'*40, f'{i}', '-'*40)
    
    query1 = (f"""SELECT COUNT(*) FROM {i}""")
    query2 = (f"""SELECT * FROM {i} LIMIT 5""")
    
    temp1_df = pd.read_sql(query1, con=engine)
    temp2_df = pd.read_sql(query2, con=engine)
    
    print(f"Total Records: {temp1_df.iloc[0,0]} \nTotal Columns: {temp2_df.shape[1]}")
    print(temp2_df.dtypes)
    display(temp2_df.head(5))
# Out:
# --- Database Audit ---
# ---------------------------------------- begin_inventory ----------------------------------------
# Total Records: 206529
# Total Columns: 9
# InventoryId     object
# Store            int64
# City            object
# Brand            int64
# Description     object
# Size            object
# onHand           int64
# Price          float64
# startDate       object
# dtype: object
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# ...

# %%
pd.read_sql_query(f"""SELECT * FROM purchases WHERE "VendorNumber" = 1128 LIMIT 5""", con=engine)
# Out:
#          InventoryId  Store  Brand                   Description   Size  \
# 0    54_GUTHRAM_2062     54   2062      Woodford Reserve Bourbon  1.75L
# 1   30_CULCHETH_3614     30   3614               Finlandia Vodka  1.75L
# 2  38_GOULCREST_1060     38   1060  Jack Daniels Bruins Glass Pk  Liter
# 3   15_WANBORNE_2143     15   2143                 Canadian Mist  1.75L
# 4    69_MOUNTMEND_62     69     62      Herradura Silver Tequila  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          1128  BROWN-FORMAN CORP                8150  2023-12-23
# 1          1128  BROWN-FORMAN CORP                8150  2023-12-23
# 2          1128  BROWN-FORMAN CORP                8150  2023-12-23
# 3          1128  BROWN-FORMAN CORP                8150  2023-12-23
# 4          1128  BROWN-FORMAN CORP                8150  2023-12-23
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
pd.read_sql_query(f"""SELECT * FROM purchase_prices WHERE "VendorNumber" = 1128 LIMIT 5""", con=engine)
# Out:
#    Brand                 Description  Price    Size Volume  Classification  \
# 0     62    Herradura Silver Tequila  36.99   750mL    750               1
# 1     63  Herradura Reposado Tequila  38.99   750mL    750               1
# 2    171              Gentleman Jack  49.99  1750mL   1750               1
# 3    809            Southern Comfort  17.99  1000mL   1000               1
# 4    811     Jack Daniels No 7 Black  29.99  1000mL   1000               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0          28.67          1128  BROWN-FORMAN CORP
# 1          30.46          1128  BROWN-FORMAN CORP
# 2          36.76          1128  BROWN-FORMAN CORP
# 3          13.13          1128  BROWN-FORMAN CORP
# 4          19.84          1128  BROWN-FORMAN CORP

# %%
pd.read_sql_query(f"""SELECT * FROM vendor_invoice WHERE "VendorNumber" = 1128 LIMIT 5""", con=engine)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0          1128  BROWN-FORMAN CORP            2024-01-09      8150
# 1          1128  BROWN-FORMAN CORP            2024-01-15      8210
# 2          1128  BROWN-FORMAN CORP            2024-01-26      8358
# 3          1128  BROWN-FORMAN CORP            2024-02-02      8457
# 4          1128  BROWN-FORMAN CORP            2024-02-06      8517
#
#        PODate     PayDate  Quantity    Dollars  Freight        Approval
# 0  2023-12-23  2024-02-19      4684   65403.57  1808.77            None
# 1  2023-12-27  2024-02-25     23351  298902.89  1494.51  Frank Delahunt
# 2  2024-01-06  2024-02-18     11443  138035.44   690.18            None
# 3  2024-01-13  2024-02-29     12899  142492.97   755.21            None
# 4  2024-01-18  2024-03-15     23217  335055.84  1708.78  Frank Delahunt

# %%
pd.read_sql_query(f"""SELECT * FROM sales WHERE "VendorNo" = 1128 LIMIT 5""", con=engine)
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0  1_HARDERSFIELD_1051      1   1051      Woodford Reserve MC 1838  750mL
# 1  1_HARDERSFIELD_1051      1   1051      Woodford Reserve MC 1838  750mL
# 2  1_HARDERSFIELD_1060      1   1060  Jack Daniels Bruins Glass Pk  Liter
# 3  1_HARDERSFIELD_1060      1   1060  Jack Daniels Bruins Glass Pk  Liter
# 4  1_HARDERSFIELD_1060      1   1060  Jack Daniels Bruins Glass Pk  Liter
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         99.99       99.99  2024-01-04   750.0
# 1              1         99.99       99.99  2024-01-23   750.0
# 2              2         55.98       27.99  2024-01-01  1000.0
# 3              1         27.99       27.99  2024-01-02  1000.0
# 4              1         31.99       31.99  2024-01-11  1000.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.79      1128  BROWN-FORMAN CORP
# ...

# %%
query = """
SELECT "Brand", SUM("SalesQuantity") AS total_qty, SUM("SalesPrice") AS total_price, SUM("SalesDollars") AS total_dol
FROM sales
GROUP BY "Brand"
ORDER BY SUM("SalesDollars") DESC
"""

pd.read_sql(query,con=engine)
# Out:
#        Brand  total_qty  total_price   total_dol
# 0       1233   142049.0    672819.31  5101919.51
# 1       3405   160247.0    561512.37  4819073.49
# 2       8068   187140.0    461140.15  4538120.60
# 3       4261   200412.0    420050.01  4475972.88
# 4       3545   135838.0    545778.28  4223107.62
# ...      ...        ...          ...         ...
# 11232   9123        2.0         0.99        1.98
# 11233   3623        2.0         1.98        1.98
# 11234   3933        2.0         0.99        1.98
# 11235   2773        1.0         0.99        0.99
# 11236   5287        2.0         0.98        0.98
#
# [11237 rows x 4 columns]

# %%
# The CTE to join Sales, Purchases, Prices, and Freight into one Master Table

# %%
# --- STEP 2: CONSOLIDATED SQL QUERY (All Columns Restored) ---
# This CTE joins Sales, Purchases, Prices, and Freight into one Master Table
consolidated_query = """
WITH FreightSummary AS (
    SELECT "VendorNumber", SUM("Freight") as FreightCost 
    FROM vendor_invoice 
    GROUP BY "VendorNumber"
), 

PurchaseSummary AS (
    SELECT 
        p."VendorNumber",
        p."VendorName",
        p."Brand",
        p."Description",
        p."PurchasePrice",
        pp."Price" AS ActualPrice,
        pp."Volume",
        SUM(p."Quantity") AS TotalPurchaseQuantity,
        SUM(p."Dollars") AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp ON p."Brand" = pp."Brand"
    WHERE p."PurchasePrice" > 0
    GROUP BY 
        p."VendorNumber", p."VendorName", p."Brand", p."Description", 
        p."PurchasePrice", pp."Price", pp."Volume"
), 

SalesSummary AS (
    SELECT 
        "VendorNo",
        "Brand",
        SUM("SalesQuantity") AS TotalSalesQuantity,
        SUM("SalesDollars") AS TotalSalesDollars,
        SUM("SalesPrice") AS TotalSalesPrice,
        SUM("ExciseTax") AS TotalExciseTax
    FROM sales
    GROUP BY "VendorNo", "Brand"
) 

SELECT 
    ps.*,
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss 
    ON ps."VendorNumber" = ss."VendorNo" 
    AND ps."Brand" = ss."Brand"
LEFT JOIN FreightSummary fs 
    ON ps."VendorNumber" = fs."VendorNumber";
"""

# %%
# Load the consolidated data into a DataFrame
df_summary = pd.read_sql(consolidated_query, con=engine)

# %%
df_summary.head()
# Out:
#    VendorNumber                   VendorName  Brand  \
# 0          9552  M S WALKER INC               10937
# 1          6785  PALM BAY INTERNATIONAL INC   18433
# 2          9552  M S WALKER INC               36571
# 3         90017  THE IMPORTED GRAPE LLC       45577
# 4          2000  SOUTHERN WINE & SPIRITS NE   32137
#
#                    Description  PurchasePrice  actualprice Volume  \
# 0     Grahams 30-Yr Tawny Port          61.64        89.99    750
# 1           Bertani Amarone 04          62.91        94.99    750
# 2  Matanzas Creek Chard Sonoma          16.33        25.99    750
# 3    Pacifico Sur Chard Curico           2.80         5.29    750
# 4       F Coppola Diamond Znfd           9.39        15.99    750
#
#    totalpurchasequantity  totalpurchasedollars  totalsalesquantity  \
# 0                   15.0                924.60                15.0
# 1                    7.0                440.37                63.0
# ...

# %%
df_summary.describe().T
# Out:
#                          count          mean            std    min  \
# VendorNumber           10692.0  10650.649458   18753.519148   2.00
# Brand                  10692.0  18039.228769   12662.187074  58.00
# PurchasePrice          10692.0     24.385303     109.269375   0.36
# actualprice            10692.0     35.643671     148.246016   0.49
# totalpurchasequantity  10692.0   3140.886831   11095.086769   1.00
# totalpurchasedollars   10692.0  30106.693372  123067.799627   0.71
# totalsalesquantity     10514.0   3129.583317   11037.801407   1.00
# totalsalesdollars      10514.0  42954.173834  168977.755843   1.98
# totalsalesprice        10514.0  19111.958773   45264.605387   0.99
# totalexcisetax         10514.0   1804.263569   11065.659557   0.06
# freightcost            10692.0  61433.763214   60938.458032   0.09
#
#                               25%        50%         75%         max
# VendorNumber            3951.0000   7153.000   9552.0000   201359.00
# ...

# %%
df_summary.shape
# Out:
# (10692, 14)

# %%
df_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# actualprice              float64
# Volume                    object
# totalpurchasequantity    float64
# totalpurchasedollars     float64
# totalsalesquantity       float64
# totalsalesdollars        float64
# totalsalesprice          float64
# totalexcisetax           float64
# freightcost              float64
# dtype: object

# %%
df_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# actualprice                0
# Volume                     0
# totalpurchasequantity      0
# totalpurchasedollars       0
# totalsalesquantity       178
# totalsalesdollars        178
# totalsalesprice          178
# totalexcisetax           178
# freightcost                0
# dtype: int64

# %%
df_summary.nunique()
# Out:
# VendorNumber               126
# VendorName                 129
# Brand                    10663
# Description               9651
# PurchasePrice             2150
# actualprice                342
# Volume                      31
# totalpurchasequantity     3876
# totalpurchasedollars      9844
# totalsalesquantity        3808
# totalsalesdollars         9616
# totalsalesprice           9040
# totalexcisetax            8043
# freightcost                126
# dtype: int64

# %%
df_summary['VendorName'].unique()
# Out:
# array(['M S WALKER INC             ', 'PALM BAY INTERNATIONAL INC ',
#        'THE IMPORTED GRAPE LLC     ', 'SOUTHERN WINE & SPIRITS NE ',
#        'E & J GALLO WINERY         ', 'MARTIGNETTI COMPANIES',
#        'PSP WINES ', 'SAZERAC CO INC             ',
#        'CAMPARI AMERICA            ', 'PERFECTA WINES             ',
#        'DIAGEO NORTH AMERICA INC   ', 'MAJESTIC FINE WINES        ',
#        'JIM BEAM BRANDS COMPANY    ', 'STELLAR IMPORTING CO LLC   ',
#        'MHW LTD                    ', 'WINE GROUP INC             ',
#        'STATE WINE & SPIRITS   ', 'LATITUDE BEVERAGE COMPANY  ',
#        'Circa Wines                ', 'CONSTELLATION BRANDS INC   ',
#        'VINILANDIA USA             ', 'DELICATO VINEYARDS INC     ',
#        'STE MICHELLE WINE ESTATES  ', 'TREASURY WINE ESTATES      ',
#        'PROXIMO SPIRITS INC.       ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'BROWN-FORMAN CORP          ', 'PREMIER DISTRIBUTORS       ',
# ...

# %%
df_summary['Description'].unique()
# Out:
# array(['Grahams 30-Yr Tawny Port', 'Bertani Amarone 04',
#        'Matanzas Creek Chard Sonoma', ..., 'Tilia Bonarda Mendoza',
#        'Fortant Heritage Lang Rouge', 'Darkhorse Cab Svgn'],
#       shape=(9651,), dtype=object)

# %%
# --- DATA CLEANING ---

# 1. Fill NaNs (Items bought but not yet sold should have 0 sales, not NaN)
cols_to_fix = ['totalsalesquantity', 'totalsalesdollars', 'totalsalesprice', 'totalexcisetax']
df_summary[cols_to_fix] = df_summary[cols_to_fix].fillna(0)

# %%
# 2. Correcting Volume's datatype
df_summary['Volume'] = df_summary['Volume'].astype('float64')

# 3. Cleaning the Empty Space in Vendor's Name
df_summary['VendorName'] = df_summary['VendorName'].str.strip()

# %%
# --- FEATURE ENGINEERING ---

# 1. Gross Profit = Sales Revenue - Cost of Goods Sold
# Note: We use 'TotalPurchaseDollars' as our cost basis here

df_summary['GrossProfit'] = df_summary['totalsalesdollars'] - df_summary['totalpurchasedollars']

# %%
# 2. Profit Margin % Calculation
# Handling division by zero using np.where

df_summary['ProfitMargin'] = np.where(
    df_summary['totalsalesdollars'] > 0, 
    (df_summary['GrossProfit'] / df_summary['totalsalesdollars']) * 100, 
    0
)

# %%
# 3. Inventory Related Features

# Unsold Inventory
df_summary['UnsoldInventory'] = df_summary['totalpurchasequantity'] - df_summary['totalsalesquantity']

# Stock Turnover
df_summary['StockTurnover'] = df_summary['totalsalesquantity'] / df_summary['totalpurchasequantity']

# Sales To Purchase Ratio
df_summary['SalesToPurchaseRatio'] = df_summary['totalsalesdollars'] / df_summary['totalpurchasedollars']

# %%
df_summary
# Out:
#        VendorNumber                  VendorName  Brand  \
# 0              9552              M S WALKER INC  10937
# 1              6785  PALM BAY INTERNATIONAL INC  18433
# 2              9552              M S WALKER INC  36571
# 3             90017      THE IMPORTED GRAPE LLC  45577
# 4              2000  SOUTHERN WINE & SPIRITS NE  32137
# ...             ...                         ...    ...
# 10687         10754              PERFECTA WINES  25381
# 10688          9744    FREDERICK WILDMAN & SONS  25425
# 10689          9552              M S WALKER INC  25544
# 10690         10754              PERFECTA WINES  26442
# 10691          3252          E & J GALLO WINERY  17876
#
#                        Description  PurchasePrice  actualprice  Volume  \
# 0         Grahams 30-Yr Tawny Port          61.64        89.99   750.0
# 1               Bertani Amarone 04          62.91        94.99   750.0
# 2      Matanzas Creek Chard Sonoma          16.33        25.99   750.0
# ...

# %%
# --- SAVING TO DATABASE FOR ADVANCED ANALYSIS ---

# We save this final table as 'vendor_summary'

df_summary.to_sql('vendor_summary', con=engine, if_exists='replace', index=False)

print("\n✅ Success! Cleaned table 'vendor_summary' created in PostgreSQL.")
# Out:
# ✅ Success! Cleaned table 'vendor_summary' created in PostgreSQL.

# %%
df_summary.describe().T
# Out:
#                          count          mean            std           min  \
# VendorNumber           10692.0  10650.649458   18753.519148      2.000000
# Brand                  10692.0  18039.228769   12662.187074     58.000000
# PurchasePrice          10692.0     24.385303     109.269375      0.360000
# actualprice            10692.0     35.643671     148.246016      0.490000
# Volume                 10692.0    847.360550     664.309212     50.000000
# totalpurchasequantity  10692.0   3140.886831   11095.086769      1.000000
# totalpurchasedollars   10692.0  30106.693372  123067.799627      0.710000
# totalsalesquantity     10692.0   3077.482136   10952.851391      0.000000
# totalsalesdollars      10692.0  42239.074419  167655.265984      0.000000
# totalsalesprice        10692.0  18793.783627   44952.773386      0.000000
# totalexcisetax         10692.0   1774.226259   10975.582240      0.000000
# freightcost            10692.0  61433.763214   60938.458032      0.090000
# ...
